# %% [markdown]
# # Basic Data Cleaning With pandas
#
# Course consists of 16 videos(including introduction). Pandas has hundreds of methods. In this course you will:
# 1. Set up Virtual Environment
# 2. Clean three dirty data sets
#     - Olympics (csv)
#     - University Towns (plain text file)
#     - Books (inconsistent format)
#
#
# ## Video 2: Setting Up Your Work Environment
# No notes from video that are relevant to online jupyter notebook

# %% [markdown]
# ## Video 3: Exploring the Olympic Data

# %%
import pandas as pd

def read():
    return pd.read_csv("pandas-data-cleaning/data-sets/olympics.csv", header=1).rename(columns={
        "Unnamed: 0": "country",
        "? Summer": "summer_olympics",
        "01 !": "summer_golds",
        "02 !": "summer_silvers",	
        "03 !": "summer_bronze",
        "Total": "summer_total",
        "? Winter": "winter_olympics",
        "01 !.1": "winter_golds",
        "02 !.1": "winter_silvers",	
        "03 !.1": "winter_bronze",
        "Total.1": "winter_total",
        "? Games": "total_games",
        "01 !.2": "total_golds",
        "02 !.2": "total_silvers",	
        "03 !.2": "total_bronze",
        "Combined total": "combined_total",

    })

# %% [markdown]
# Running the function created in the previous cell

# %%
olympics = read()

# %%
olympics.head()
# Out:
#                    country  summer_olympics  summer_golds  summer_silvers  \
# 0        Afghanistan (AFG)               13             0               0
# 1            Algeria (ALG)               12             5               2
# 2          Argentina (ARG)               23            18              24
# 3            Armenia (ARM)                5             1               2
# 4  Australasia (ANZ) [ANZ]                2             3               4
#
#    summer_bronze  summer_total  winter_olympics  winter_golds  winter_silvers  \
# 0              2             2                0             0               0
# 1              8            15                3             0               0
# 2             28            70               18             0               0
# 3              9            12                6             0               0
# 4              5            12                0             0               0
#
# ...

# %%
# %%
# using the location indexer to return rows. Inclusive
olympics.loc[0:5]


# %%
united_countries =olympics.loc[:, 'country'].str.contains('United')
olympics.loc[united_countries, :]
# %%
# Out:
#                                  country  summer_olympics  summer_golds  \
# 45    United Team of Germany (EUA) [EUA]                3            28
# 134           United Arab Emirates (UAE)                8             1
# 135  United States (USA) [P] [Q] [R] [Z]               26           976
#
#      summer_silvers  summer_bronze  summer_total  winter_olympics  \
# 45               54             36           118                3
# 134               0              0             1                0
# 135             757            666          2399               22
#
#      winter_golds  winter_silvers  winter_bronze  winter_total  total_games  \
# 45              8               6              5            19            6
# 134             0               0              0             0            8
# 135            96             102             84           282           48
#
#      total_golds  total_silvers  total_bronze  combined_total
# ...
